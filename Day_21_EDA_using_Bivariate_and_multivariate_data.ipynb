# %% [markdown]
# <a href="https://colab.research.google.com/github/poonamkhot123/Machine-Learning-Practice-Hub/blob/main/Day_21_EDA_using_Bivariate_and_multivariate_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = pd.read_csv("/content/tip.csv")

# %%
titanic = pd.read_csv("/content/tested.csv")

# %%
flights = pd.read_csv("/content/flights_data.csv")

# %%
iris = pd.read_csv("/content/iris.csv")

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# # 1 Scatterplot(Numerical - Numerical)

# %%
sns.scatterplot(x=tips['total_bill'], y=tips['tip'],hue=tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 2.bar plot (numerical - categorical)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
sns.barplot(x = titanic['Pclass'],y = titanic['Fare'],hue = titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# # 3 Box plot (numerical - categorical)

# %%
sns.boxplot(x = titanic['Sex'],y = titanic['Age'],hue =titanic['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # 4.Distplot (numerical - categorical)

# %%
sns.distplot(titanic[titanic["Survived"]==0]['Age'],hist=False)
sns.distplot(titanic[titanic["Survived"]==1]['Age'],hist=False)
# Out:
# /tmp/ipykernel_1201/1614813482.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic["Survived"]==0]['Age'],hist=False)
# /tmp/ipykernel_1201/1614813482.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic["Survived"]==1]['Age'],hist=False)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # 5.Heatmap (Categorical - Categorical)

# %%
titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic["Survived"]))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic['Survived'] = titanic['Survived'].astype(int)
(titanic.groupby('Pclass')['Survived'].mean()*100).plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
titanic.groupby('Embarked').mean(["Survived"]*100)
# Out:
#           PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Embarked
# C         1094.676471  0.392157  1.794118  34.737805  0.421569  0.382353
# Q         1088.239130  0.521739  2.869565  29.318182  0.195652  0.021739
# S         1104.788889  0.325926  2.340741  28.758772  0.500000  0.459259
#
#                Fare
# Embarked
# C         66.259765
# Q         10.957700
# S         28.230436

# %% [markdown]
# # 6. Clustered map(categorical - categorical)

# %%
sns.clustermap(pd.crosstab(titanic['SibSp'],titanic['Survived']))

# %% [markdown]
# # 7 Pairplot

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# # 8.lineplot ( numerical = numerical)

# %%
flights.head()
# Out:
#    Unnamed: 0 flight_date flight_status departure_airport departure_timezone  \
# 0           0  2024-09-05     scheduled          Shenzhen      Asia/Shanghai
# 1           1  2024-09-05     scheduled  Singapore Changi     Asia/Singapore
# 2           2  2024-09-05     scheduled  Singapore Changi     Asia/Singapore
# 3           3  2024-09-05     scheduled  Singapore Changi     Asia/Singapore
# 4           4  2024-09-05     scheduled  Singapore Changi     Asia/Singapore
#
#   departure_gate departure_terminal       arrival_airport   arrival_timezone  \
# 0            NaN                 T3  Penang International  Asia/Kuala_Lumpur
# 1            F52                  2  Penang International  Asia/Kuala_Lumpur
# 2            F52                  2  Penang International  Asia/Kuala_Lumpur
# 3            F52                  2  Penang International  Asia/Kuala_Lumpur
# 4            F52                  2  Penang International  Asia/Kuala_Lumpur
#
#   arrival_terminal arrival_gate      airline_name
# 0              NaN          NaN     Air China LTD
# 1              NaN          NaN  Virgin Australia
# 2              NaN          NaN           Vistara
# 3              NaN          NaN   United Airlines
# 4              NaN          NaN   Air New Zealand

# %%
flights.head()
# Out:
#    Unnamed: 0 flight_date flight_status departure_airport departure_timezone  \
# 0           0  2024-09-05     scheduled          Shenzhen      Asia/Shanghai
# 1           1  2024-09-05     scheduled  Singapore Changi     Asia/Singapore
# 2           2  2024-09-05     scheduled  Singapore Changi     Asia/Singapore
# 3           3  2024-09-05     scheduled  Singapore Changi     Asia/Singapore
# 4           4  2024-09-05     scheduled  Singapore Changi     Asia/Singapore
#
#   departure_gate departure_terminal       arrival_airport   arrival_timezone  \
# 0            NaN                 T3  Penang International  Asia/Kuala_Lumpur
# 1            F52                  2  Penang International  Asia/Kuala_Lumpur
# 2            F52                  2  Penang International  Asia/Kuala_Lumpur
# 3            F52                  2  Penang International  Asia/Kuala_Lumpur
# 4            F52                  2  Penang International  Asia/Kuala_Lumpur
#
#   arrival_terminal arrival_gate      airline_name
# 0              NaN          NaN     Air China LTD
# 1              NaN          NaN  Virgin Australia
# 2              NaN          NaN           Vistara
# 3              NaN          NaN   United Airlines
# 4              NaN          NaN   Air New Zealand
